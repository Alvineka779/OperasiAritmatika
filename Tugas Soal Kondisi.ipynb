# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvineka779/PPLG-KEV/blob/main/Tugas%20Soal%20Kondisi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Buatlah sebuah program untuk menentukan bilangan positif, bilangan negatif,dan bilangan 0!**

# %%
#Menginput Angka
angka = float(input("Tulis Sebuah Angka: "))

#Menampilkan Kondisi Angka Positif
if angka > 0 :
  print("Bilangan Positif")

#Menampilkan Kondisi Angka Nol
elif angka == 0:
  print("Bilangan Nol")

#Menampilkan Kondisi Angka Negatif
else:
  print("Bilangan Negatif")

# %% [markdown]
# **Algoritma :**
#
# - Input Data
# - Jika Angka Lebih Dari 0 Maka Hasilnya Positif
# - Jika Angka Sama Dengan 0 Maka Hasilnya 0
# - Jika Angka Kurang dari 0 Maka Hasilnya Negatif
#
# **Flowchart :**
#
# ![Flowcharts(2).png](data:image/png;base64,...)

# %% [markdown]
# # **Sebuah toko sepatu menawarkan diskon 10% untuk pembelian sepatu dengan harga lebih dari Rp.500.000 Dan Diskon 5% untuk pembelian sepatu lebih dari Rp100.000.buatlah program pyton untuk menghitung harga akhir pembelian sepatu menggunakan "if", buatkanlah juga algoritma dan flowchartnya!**

# %%
print('##  Program Python Diskon Potongan Harga  ##')
print('============================================')
print()

total_belanja = int(input('Total Belanja: Rp.'))

if (total_belanja >= 100000) and (total_belanja < 500000):
  harga_akhir = total_belanja - (0.1*total_belanja)
  print('Selamat, anda mendapat diskon 10%')
elif (total_belanja >= 500000) and (total_belanja < 1000000):
  harga_akhir = total_belanja - (0.05*total_belanja)
  print('Selamat, anda mendapat diskon 5%')
else:
  harga_akhir = total_belanja

print('Total bayar: Rp.',round(harga_akhir,2))

# %% [markdown]
# # Algoritma :
# - Input Data
# - Jika Harga Lebih dari sama dengan Rp.100.000 dan Apabila Harga Kurang Dari Rp.500.000 Maka Mendapatkan Diskon Sebesar 10%
# - Jika Harga Lebih dari sama dengan Rp.500.000 dan Apabila Harga Kurang Dari Rp.100.000 Maka Mendapatkan Diskon Sebesar 5%
#
#
# #Flowchart :
#
# ![Flowcharts(1).png](data:image/png;base64,...)

# %% [markdown]
# # **buatlah game sederhana menggunakan bahasa python berserta algoritma dan flowchartnya!**

# %%
                       import random


                       import math


                       # Taking Inputs


                       lower = int(input("Masukan Angka anda:- "))





                       # Taking Inputs


                       upper = int(input("Masukan Sekali lagi:- "))





                       # generating random number between


                       # the lower and upper


                       x = random.randint(lower, upper)


                       print("\n\tYou've only ",


                       	round(math.log(upper - lower + 1, 2)),


                       	" chances to guess the integer!\n")





                       # Initializing the number of guesses.


                       count = 0





                       # for calculation of minimum number of


                       # guesses depends upon range


                       while count < math.log(upper - lower + 1, 2):


                       	count += 1





                       	# taking guessing number as input


                       	guess = int(input("Guess a number:- "))





                       	# Condition testing


                       	if x == guess:


                       		print("Selamat anda Berhasil Menebak",


                       			count, " Ulang")


                       		# Once guessed, loop will break


                       		break


                       	elif x > guess:


                       		print("Anda menebak terlalu kecil!")


                       	elif x < guess:


                       		print("Anda menebak terlalu Besar!")





                       # If Guessing is more than required guesses,


                       # shows this output.


                       if count >= math.log(upper - lower + 1, 2):


                       	print("\nNomor anda adalah  %d" % x)


                       	print("\tSemoga lain kali lebih beruntung!")





                       # Better to use This source Code on pycharm!

# %% [markdown]
# # Algoritma :
# - Input Data:
# - Anda Harus Memasukan Angka Pertama
# - Anda Harus Memasukan Angka Kedua untuk Konfirmasi
# - Hasil Akan Muncul Kalau Anda Benar
#
# #Flowchart :
#
# ![Flowcharts(3).png](data:image/png;base64,...)

# %% [markdown]
# # **Buatlah sebuah program sederhana menggunakan perulangan dan buatkan algoritma dan flowchartnya**

# %%
bilangan = [i for i in range(1, 10)]

i = 0
while i < len(bilangan):
    if bilangan[i] % 2 == 0:
        print(bilangan[i], "adalah bilangan genap")
    else:
        print(bilangan[i], "adalah bilangan ganjil")
    i += 1

# %% [markdown]
# # Algoritma :
# - Input Data
# - Data akan Mengulang sesuai angka yang di input
#
# #Flowchart :
#
# ![Flowcharts(4).png](data:image/png;base64,...)
